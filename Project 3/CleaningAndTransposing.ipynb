# %%
import pandas as pd
from os import getcwd, listdir, chdir
from os.path import splitext

chdir("../..")

# %%
data_path = getcwd() +  "/data/raw"

list_of_files = [file for file in listdir(data_path) if 'Onet' in file]

list_of_files
# Out:
# ['Onet_JobZones.csv',
#  'Onet_Knowledge.csv',
#  'Onet_WorkActivities.csv',
#  'Onet_WorkContext.csv']

# %%
# Read All the Files as CSVs into a Dictionary
data_dict = {splitext(key)[0].split("_")[1]: pd.read_csv(f"{data_path}/{key}") for key in list_of_files}

# Select DataFrames for Transposing
transpose_dict = {k:v for k,v in data_dict.items() if k in list(data_dict.keys())[1:]}

transpose_dict.keys() 
transpose_dict['WorkContext'].columns # Testing


# Creating a Function to apply Filter to All the Files
def clean_filter(df, scale_name_category):

    df = df[df['Scale_Name'] == scale_name_category]

    filtered_cols = ['SOC_Code', 'Title', 'Element_ID', 'Element_Name', 'Scale_Name', 'Data_Value']

    important_df = df[filtered_cols]

    return important_df


## Transpose from Pandas Transform

# Helper Function
def transform(sub_df):
    # Create a selection to perform a transpose
    transpose_test = sub_df[['Element_Name', 'Data_Value']].T
    transpose_test.columns = transpose_test.iloc[0]
    second_frame = transpose_test[1:].reset_index().drop('index', axis=1)

    # First Frame (Info that stays the same)
    code_title_frame = sub_df[['SOC_Code', 'Title']].iloc[0:1]
    first_frame = code_title_frame.reset_index().drop('index', axis=1)

    return pd.concat([first_frame, second_frame], axis=1)

## Wrap as function
def transpose_func(df, n):
    # Getting Number of Partitions
    partition_count = int(df.shape[0] / n)

    # Empty List to store partitions
    temp_df_partitions = []

    # Going through each partition
    for i in range(partition_count):
        # Getting a specific partition
        temp_df = df.iloc[i*n:(i+1)*n]
        # Applying transform to partition
        temp_df = transform(temp_df)
        # Adding transformed partition into partition list
        temp_df_partitions.append(temp_df)

    # Consolidating all partitions into single DataFrame
    final_df = pd.concat(temp_df_partitions)

    return final_df

# Output to CSV
output_path = getcwd() + "/data/sas_to_pandas/transformed"

# Applying Cleaning to Knowledge Wide
knowledge_2 = clean_filter(transpose_dict['Knowledge'], 'Importance')

knowledge_wide = transpose_func(knowledge_2, 33)

# knowledge_wide.to_csv(f"{output_path}/KNOWLEDGE_WIDE.csv", index=False)

# Applying Cleaning to Work Activities
work_activity_2 = clean_filter(transpose_dict['WorkActivities'], 'Importance')
work_activity_wide = transpose_func(work_activity_2, 41)
# work_activity_wide.to_csv(f"{output_path}/WORK_ACTIVITY_WIDE.csv", index=False)

# Applying Cleaning to Work Context
work_context_2 = clean_filter(transpose_dict['WorkContext'], 'Context')
work_context_wide = transpose_func(work_context_2, 57)
# work_context_wide.to_csv(f"{output_path}/WORK_CONTEXT_WIDE.csv", index=False)

# Cleaning Job Zone
cols_to_keep = data_dict['JobZones'].columns.tolist()[:3]
job_zones_2 = data_dict['JobZones'][cols_to_keep]
# job_zones_2.to_csv(f"{output_path}/Job_Zones_2.csv", index=False)

# %%
knowledge_wide.head()
# Out:
#      SOC_Code                                Title  \
# 0  11-1011.00                     Chief Executives
# 0  11-1011.03        Chief Sustainability Officers
# 0  11-1021.00      General and Operations Managers
# 0  11-2011.00  Advertising and Promotions Managers
# 0  11-2021.00                   Marketing Managers
#
#   Administration_and_Management Administrative Economics and Accounting  \
# 0                          4.75           2.66                      3.7
# 0                          4.15           2.62                     3.19
# 0                          4.35           3.51                     3.47
# 0                          4.12           3.25                     3.04
# 0                          4.04           3.01                      3.1
#
#   Sales and Marketing Customer and Personal Service  \
# 0                3.23                          4.09
# 0                3.15                          3.41
# 0                3.47                          3.95
# 0                4.68                          4.16
# 0                4.85                          3.85
#
#   Personnel and Human Resources Production and Processing Food Production  \
# 0                           4.1                      2.63            1.14
# 0                           3.0                      2.19            2.07
# 0                          3.76                      3.39            1.34
# 0                           2.6                      2.58            1.04
# 0                          2.71                      2.46            1.12
#
#    ... English Language Foreign Language Fine Arts History and Archeology  \
# 0  ...             4.07             1.56      1.43                   1.48
# 0  ...              4.3             1.85      1.63                   2.31
# 0  ...             3.71             1.62      1.16                   1.21
# 0  ...             4.41             1.58      2.35                   1.67
# 0  ...             4.48             1.64       1.7                   1.68
#
#   Philosophy and Theology Public Safety and Security Law and Government  \
# 0                     1.7                        3.3               3.92
# 0                    2.11                       2.56               3.69
# 0                    1.51                        3.1               2.95
# 0                    1.89                       2.47               2.23
# 0                    1.64                        2.5               2.86
#
#   Telecommunications Communications and Media Transportation
# 0               1.76                      2.7           2.21
# 0               1.89                     3.56           3.11
# 0                2.5                     2.59            2.2
# 0                2.4                     4.35           1.95
# 0               2.86                      3.8           1.68
#
# [5 rows x 35 columns]

# %%
work_activity_wide.head()
# Out:
#      SOC_Code                                Title Getting Information  \
# 0  11-1011.00                     Chief Executives                4.72
# 0  11-1011.03        Chief Sustainability Officers                4.78
# 0  11-1021.00      General and Operations Managers                4.26
# 0  11-2011.00  Advertising and Promotions Managers                4.32
# 0  11-2021.00                   Marketing Managers                4.33
#
#   Monitoring Processes, Materials, or Surroundings  \
# 0                                             3.68
# 0                                             3.48
# 0                                             4.07
# 0                                             2.78
# 0                                             3.27
#
#   Identifying Objects, Actions, and Events  \
# 0                                      4.2
# 0                                     3.85
# 0                                     4.14
# 0                                      3.6
# 0                                     4.24
#
#   Inspecting Equipment, Structures, or Materials  \
# 0                                           2.38
# 0                                           2.11
# 0                                           3.43
# 0                                           1.77
# 0                                           1.45
#
#   Estimating the Quantifiable Characteristics of Products, Events, or Information  \
# 0                                               3.59
# 0                                               3.54
# 0                                               3.58
# 0                                               2.79
# 0                                               3.59
#
#   Judging the Qualities of Objects, Services, or People  \
# 0                                               4.35
# 0                                               3.85
# 0                                               4.06
# 0                                               3.37
# 0                                               3.37
#
#   Processing Information  \
# 0                   4.03
# 0                   3.96
# 0                   3.96
# 0                   3.51
# 0                   3.36
#
#   Evaluating Information to Determine Compliance with Standards  ...  \
# 0                                               4.22             ...
# 0                                               3.67             ...
# 0                                               4.01             ...
# 0                                               2.35             ...
# 0                                               2.61             ...
#
#   Performing for or Working Directly with the Public  \
# 0                                               2.94
# 0                                               3.56
# 0                                               3.85
# 0                                               3.18
# 0                                               2.81
#
#   Coordinating the Work and Activities of Others  \
# 0                                           3.93
# 0                                           4.07
# 0                                           4.24
# 0                                           3.07
# 0                                           3.97
#
#   Developing and Building Teams Training and Teaching Others  \
# 0                          4.55                          3.0
# 0                          4.19                         3.63
# 0                          3.98                         3.94
# 0                          2.96                         2.74
# 0                          4.08                         3.14
#
#   Guiding, Directing, and Motivating Subordinates  \
# 0                                            4.57
# 0                                            3.78
# 0                                            4.15
# 0                                            2.98
# 0                                            3.84
#
#   Coaching and Developing Others Providing Consultation and Advice to Others  \
# 0                           3.92                                        3.65
# 0                           3.93                                        3.93
# 0                           3.93                                        3.17
# 0                           2.62                                        2.31
# 0                           3.36                                        3.18
#
#   Performing Administrative Activities Staffing Organizational Units  \
# 0                                 3.14                           3.7
# 0                                  3.3                          3.26
# 0                                 3.49                          3.46
# 0                                 3.11                          2.29
# 0                                 2.59                          2.25
#
#   Monitoring and Controlling Resources
# 0                                 4.43
# 0                                 3.88
# 0                                 3.81
# 0                                 2.52
# 0                                 3.18
#
# [5 rows x 43 columns]

# %%
work_context_wide.head()
# Out:
#      SOC_Code                                Title Public Speaking Telephone  \
# 0  11-1011.00                     Chief Executives            3.39       5.0
# 0  11-1011.03        Chief Sustainability Officers            2.93      4.74
# 0  11-1021.00      General and Operations Managers            2.87      4.93
# 0  11-2011.00  Advertising and Promotions Managers            2.55       4.8
# 0  11-2021.00                   Marketing Managers            3.35      4.92
#
#   Electronic Mail Letters and Memos Face-to-Face Discussions  \
# 0             5.0              4.33                     4.98
# 0             5.0              3.44                     4.67
# 0            4.85              3.95                     4.95
# 0             5.0              3.78                     4.87
# 0             5.0              3.52                     4.76
#
#   Contact With Others Work With Work Group or Team  \
# 0                 4.8                         4.74
# 0                4.41                         4.78
# 0                4.79                         4.79
# 0                4.68                         4.47
# 0                4.61                         4.67
#
#   Deal With External Customers  ... Freedom to Make Decisions  \
# 0                         4.33  ...                      4.91
# 0                         3.85  ...                      4.37
# 0                         4.13  ...                      4.78
# 0                         4.19  ...                      4.04
# 0                         4.25  ...                      4.42
#
#   Degree of Automation Importance of Being Exact or Accurate  \
# 0                 2.68                                  4.16
# 0                 1.56                                  3.52
# 0                 2.27                                  3.99
# 0                 2.01                                   4.3
# 0                  2.1                                  3.81
#
#   Importance of Repeating Same Tasks Structured versus Unstructured Work  \
# 0                               3.23                                4.98
# 0                               1.81                                4.44
# 0                               3.59                                 4.8
# 0                                2.7                                4.23
# 0                               2.78                                4.63
#
#   Level of Competition Time Pressure Pace Determined by Speed of Equipment  \
# 0                 4.18           4.2                                  1.66
# 0                  3.7          3.48                                  1.19
# 0                 3.44          4.22                                   1.6
# 0                 3.34           4.4                                   1.0
# 0                 3.95          4.21                                  1.02
#
#   Work Schedules Duration of Typical Work Week
# 0            1.3                          2.89
# 0           1.08                          2.74
# 0           1.15                          2.86
# 0            1.2                          2.48
# 0           1.26                          2.78
#
# [5 rows x 59 columns]

# %%
job_zones_2.head()
# Out:
#      SOC_Code                                Title  Job_Zone
# 0  11-1011.00                     Chief Executives         5
# 1  11-1011.03        Chief Sustainability Officers         5
# 2  11-1021.00      General and Operations Managers         4
# 3  11-1031.00                          Legislators         4
# 4  11-2011.00  Advertising and Promotions Managers         4
