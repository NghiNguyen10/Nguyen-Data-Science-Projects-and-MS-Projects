# %%
import pandas as pd
from os import getcwd, listdir
from warnings import filterwarnings

filterwarnings('ignore')

data_path = getcwd() + "/data/sas_to_pandas/joins"

df = pd.read_csv(f"{data_path}/Skillshed.csv")

# Create the Grow List
grow_list = pd.DataFrame({'SOC_Code': list(set(
    ['25-2011.00', '29-2052.00', '31-1131.00', '31-2021.00', '31-9091.00', '33-9032.00']))})

# Create the Decline List
decline_list = pd.DataFrame({'SOC_Code': list(set(['23-2093.00', '27-1026.00', '43-3011.00', '43-3031.00', '43-3051.00', '43-3061.00',
                            '43-4071.00', '43-4151.00', '43-4161.00', '43-5032.00', '43-6011.00', '43-6014.00', '43-9021.00', '43-9061.00']))})

# Create the OCC List

## Group the SOC Codes in both lists together
occ_list = pd.concat([decline_list, grow_list]
                     ).reset_index().drop('index', axis=1)

## Set the Grow column to Yes
occ_list['Grow'] = 'Y'

records_to_replace = occ_list[occ_list['SOC_Code'].isin(
    decline_list['SOC_Code'].tolist())].index

# Replacing values based on index: Use .loc
## First argument is the index values, second is the column name
## Right side of = will be the new value
## https://stackoverflow.com/questions/37725195/pandas-replace-values-based-on-index
occ_list.loc[records_to_replace, 'Grow'] = 'N'

# Filter the original dataframe based on SOC Codes in the occ_list
# final_df = df[df['SOC_Code'].isin(occ_list['SOC_Code'].tolist())].reset_index().drop('index', axis=1)
final_df = occ_list.merge(df, on='SOC_Code', how='inner')

final_df.to_csv(f"{data_path}/OCC_List.csv", index=False)

# %%
final_df
# Out:
#       SOC_Code Grow                                              Title  \
# 0   43-3051.00    N                     Payroll and Timekeeping Clerks
# 1   43-4161.00    N  Human Resources Assistants, Except Payroll and...
# 2   43-5032.00    N    Dispatchers, Except Police, Fire, and Ambulance
# 3   43-6014.00    N  Secretaries and Administrative Assistants, Exc...
# 4   43-4151.00    N                                       Order Clerks
# 5   43-3011.00    N                        Bill and Account Collectors
# 6   43-3061.00    N                                 Procurement Clerks
# 7   43-9021.00    N                                  Data Entry Keyers
# 8   23-2093.00    N        Title Examiners, Abstractors, and Searchers
# 9   27-1026.00    N         Merchandise Displayers and Window Trimmers
# 10  43-9061.00    N                             Office Clerks, General
# 11  43-4071.00    N                                        File Clerks
# 12  43-6011.00    N  Executive Secretaries and Executive Administra...
# 13  43-3031.00    N       Bookkeeping, Accounting, and Auditing Clerks
# 14  25-2011.00    Y       Preschool Teachers, Except Special Education
# 15  33-9032.00    Y                                    Security Guards
# 16  31-2021.00    Y                      Physical Therapist Assistants
# 17  29-2052.00    Y                               Pharmacy Technicians
# 18  31-1131.00    Y                                 Nursing Assistants
# 19  31-9091.00    Y                                  Dental Assistants
#
#     Administration_and_Management  Administrative  Economics and Accounting  \
# 0                            3.83            4.49                      4.07
# 1                            3.47            4.11                      2.20
# 2                            3.86            3.74                      2.01
# 3                            3.43            4.52                      2.75
# 4                            2.87            3.93                      2.96
# 5                            3.07            3.07                      3.26
# 6                            3.44            3.78                      3.47
# 7                            2.72            4.56                      2.47
# 8                            1.83            3.15                      1.56
# 9                            3.15            2.25                      1.85
# 10                           3.01            4.19                      2.44
# 11                           2.77            3.96                      2.72
# 12                           3.18            4.52                      2.09
# 13                           2.87            3.89                      3.35
# 14                           2.66            2.57                      1.32
# 15                           2.19            2.15                      1.15
# 16                           2.61            2.97                      1.96
# 17                           2.87            3.31                      2.04
# 18                           3.34            2.61                      2.17
# 19                           3.47            3.45                      2.35
#
#     Sales and Marketing  Customer and Personal Service  \
# 0                  1.38                           3.21
# 1                  1.36                           3.74
# 2                  1.91                           4.34
# 3                  1.89                           3.76
# 4                  3.11                           4.33
# 5                  2.14                           3.77
# 6                  2.14                           3.76
# 7                  1.97                           3.59
# 8                  1.77                           3.11
# 9                  3.78                           3.85
# 10                 2.05                           3.44
# 11                 2.09                           3.48
# 12                 1.51                           3.46
# 13                 1.85                           4.18
# 14                 2.09                           3.20
# 15                 1.49                           3.17
# 16                 1.83                           4.52
# 17                 2.25                           4.59
# 18                 2.30                           3.92
# 19                 3.31                           4.54
#
#     Personnel and Human Resources  Production and Processing  ...  \
# 0                            3.90                       1.39  ...
# 1                            4.41                       1.33  ...
# 2                            3.25                       1.97  ...
# 3                            2.73                       1.73  ...
# 4                            2.35                       3.08  ...
# 5                            1.74                       2.35  ...
# 6                            2.39                       2.72  ...
# 7                            2.02                       2.32  ...
# 8                            1.26                       2.31  ...
# 9                            2.33                       2.00  ...
# 10                           2.33                       1.79  ...
# 11                           2.80                       2.48  ...
# 12                           2.77                       1.39  ...
# 13                           2.15                       1.68  ...
# 14                           2.12                       1.37  ...
# 15                           2.10                       1.30  ...
# 16                           2.13                       1.28  ...
# 17                           2.62                       3.24  ...
# 18                           2.66                       2.20  ...
# 19                           2.93                       3.06  ...
#
#     Degree of Automation  Importance of Being Exact or Acc  \
# 0                   2.79                              4.91
# 1                   2.55                              4.72
# 2                   2.43                              4.58
# 3                   1.79                              4.22
# 4                   2.65                              4.20
# 5                   2.86                              4.04
# 6                   1.99                              4.85
# 7                   2.85                              4.87
# 8                   3.03                              5.00
# 9                   1.46                              3.23
# 10                  2.10                              4.60
# 11                  2.03                              4.58
# 12                  2.06                              4.50
# 13                  2.36                              4.68
# 14                  1.56                              3.35
# 15                  1.60                              4.38
# 16                  1.43                              3.36
# 17                  2.44                              4.98
# 18                  1.77                              4.54
# 19                  1.93                              4.37
#
#     Importance of Repeating Same Tas  Structured versus Unstructured W  \
# 0                               4.57                              3.64
# 1                               4.36                              4.22
# 2                               4.50                              4.29
# 3                               4.30                              4.28
# 4                               4.24                              4.26
# 5                               4.30                              3.37
# 6                               4.57                              4.36
# 7                               4.81                              4.25
# 8                               4.36                              4.69
# 9                               2.83                              3.72
# 10                              4.22                              3.72
# 11                              3.66                              3.75
# 12                              3.83                              4.68
# 13                              4.65                              3.80
# 14                              2.01                              3.60
# 15                              3.87                              3.65
# 16                              3.21                              4.46
# 17                              4.39                              3.51
# 18                              3.46                              3.64
# 19                              3.93                              3.44
#
#     Level of Competition  Time Pressure  Pace Determined by Speed of Equi  \
# 0                   2.42           4.25                              1.32
# 1                   2.91           4.27                              1.13
# 2                   3.01           4.48                              2.00
# 3                   2.31           4.09                              1.19
# 4                   2.91           3.88                              1.35
# 5                   3.52           3.90                              1.09
# 6                   1.76           3.42                              1.18
# 7                   2.89           4.21                              1.85
# 8                   3.39           4.41                              1.14
# 9                   3.01           3.77                              1.15
# 10                  2.09           3.77                              1.45
# 11                  2.75           3.61                              1.58
# 12                  2.41           3.86                              1.13
# 13                  2.76           3.87                              1.28
# 14                  2.49           3.07                              1.00
# 15                  3.42           2.98                              1.22
# 16                  2.49           3.52                              1.02
# 17                  2.95           4.26                              2.29
# 18                  3.01           3.71                              2.31
# 19                  2.35           3.44                              2.02
#
#     Work Schedules  Duration of Typical Work Week  Job_Zone
# 0             1.00                           2.15         3
# 1             1.06                           2.48         3
# 2             1.46                           2.62         2
# 3             1.00                           1.99         2
# 4             1.08                           2.24         2
# 5             1.00                           2.04         2
# 6             1.07                           2.22         2
# 7             1.32                           1.92         2
# 8             1.08                           2.03         2
# 9             1.42                           1.76         3
# 10            1.01                           1.89         2
# 11            1.00                           1.71         2
# 12            1.07                           2.20         3
# 13            1.01                           1.97         3
# 14            1.00                           1.63         3
# 15            1.07                           2.14         2
# 16            1.02                           1.29         3
# 17            1.19                           1.91         3
# 18            1.17                           1.92         3
# 19            1.00                           1.27         3
#
# [20 rows x 136 columns]
